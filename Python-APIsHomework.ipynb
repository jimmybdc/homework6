# %%
# Dependencies
import csv
import matplotlib.pyplot as plt
import pandas as pd
import requests as req
from random import uniform
from citipy import citipy

# %%
# Save config information.
api_key = "25bc90a1196e6f153eece0bc0b0fc9eb"
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# %%
# Build partial query URL
query_url = url + "appid=" + api_key + "&units=" + units + "&q="
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q='

# %%
# creating list
weather_data = []
cities = []

while len(cities)<600:
    latitude, longitude = uniform(-180,180), uniform(-90,90)
    city = citipy.nearest_city(latitude, longitude).city_name
    if city not in cities : 
        cities.append(city)

# %%
# creating dictionary and log
count = 1
weather_d = {"City":[],"Cloudiness":[],"Country":[],"Date":[],"Humidity":[],"Lat":[],"Lng":[],"Temp":[],"Wind Speed":[]}
for city in cities:
    temp = req.get(query_url + city).json()
    try:
        if temp["message"]=="city not found":
            continue
    except KeyError:
        print(str(count) + " of 500")
        print(temp.get("id"), city)
        print(query_url + city)
        weather_d["City"].append(temp["name"])
        weather_d["Cloudiness"].append(temp["clouds"]["all"])
        weather_d["Country"].append(temp["sys"]["country"])
        weather_d["Date"].append(temp["dt"])
        weather_d["Humidity"].append(temp["main"]["humidity"])
        weather_d["Lat"].append(temp["coord"]["lat"])
        weather_d["Lng"].append(temp["coord"]["lon"])
        weather_d["Temp"].append(temp["main"]["temp"])
        weather_d["Wind Speed"].append(temp["wind"]["speed"])
        weather_d
        count+=1
# Out:
# 1 of 500
# 7626844 kralendijk
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=kralendijk
# 2 of 500
# 1058381 morondava
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=morondava
# 3 of 500
# 3053163 szob
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=szob
# 4 of 500
# 1282256 hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=hithadhoo
# 5 of 500
# 964432 port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=port alfred
# 6 of 500
# 3443061 chuy
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=chuy
# 7 of 500
# 3386213 touros
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=touros
# 8 of 500
# 2396518 port-gentil
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=port-gentil
# 9 of 500
# 2729907 longyearbyen
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=longyearbyen
# 10 of 500
# 2966935 killybegs
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=killybegs
# 11 of 500
# 2075265 busselton
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=busselton
# 12 of 500
# 3833367 ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=ushuaia
# 13 of 500
# 1015776 bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=bredasdorp
# 14 of 500
# 988698 knysna
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=knysna
# 15 of 500
# 4501427 port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=port elizabeth
# 16 of 500
# 3792382 cartagena del chaira
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=cartagena del chaira
# 17 of 500
# 3493146 fantino
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=fantino
# 18 of 500
# 3870282 talcahuano
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=talcahuano
# 19 of 500
# 523392 naryan-mar
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=naryan-mar
# 20 of 500
# 6324733 torbay
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=torbay
# 21 of 500
# 1507390 dikson
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=dikson
# 22 of 500
# 3831208 qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=qaanaaq
# 23 of 500
# 3412093 vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=vestmannaeyjar
# 24 of 500
# 3423146 ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=ilulissat
# 25 of 500
# 3369157 cape town
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=cape town
# 26 of 500
# 5106841 albany
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=albany
# 27 of 500
# 64013 bosaso
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=bosaso
# 28 of 500
# 3421719 narsaq
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=narsaq
# 29 of 500
# 2447513 arlit
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=arlit
# 30 of 500
# 2332459 lagos
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=lagos
# 31 of 500
# 2316259 bulungu
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=bulungu
# 32 of 500
# 1733782 victoria
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=victoria
# 33 of 500
# 3372988 ribeira grande
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=ribeira grande
# 34 of 500
# 2334327 kishi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=kishi
# 35 of 500
# 3418910 upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=upernavik
# 36 of 500
# 3366880 hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=hermanus
# 37 of 500
# 3468615 arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=arraial do cabo
# 38 of 500
# 3453218 caravelas
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=caravelas
# 39 of 500
# 3139597 sistranda
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=sistranda
# 40 of 500
# 3220841 loding
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=loding
# 41 of 500
# 739600 sinop
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=sinop
# 42 of 500
# 921815 dzaoudzi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=dzaoudzi
# 43 of 500
# 1127110 sar-e pul
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=sar-e pul
# 44 of 500
# 1258338 ratnagiri
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=ratnagiri
# 45 of 500
# 5962442 goderich
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=goderich
# 46 of 500
# 3463030 foz do iguacu
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=foz do iguacu
# 47 of 500
# 4601709 rock hill
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=rock hill
# 48 of 500
# 3424607 tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=tasiilaq
# 49 of 500
# 1505991 igarka
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=igarka
# 50 of 500
# 2181133 saint andrews
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=saint andrews
# 51 of 500
# 344979 lebu
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=lebu
# 52 of 500
# 3836669 san rafael
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=san rafael
# 53 of 500
# 110690 abha
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=abha
# 54 of 500
# 3573345 hamilton
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=hamilton
# 55 of 500
# 587450 juba
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=juba
# 56 of 500
# 3397865 itaueira
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=itaueira
# 57 of 500
# 328316 sire
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=sire
# 58 of 500
# 2069194 jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=jamestown
# 59 of 500
# 1242110 kalmunai
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=kalmunai
# 60 of 500
# 2966778 ballina
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=ballina
# 61 of 500
# 3863379 mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=mar del plata
# 62 of 500
# 3440777 rocha
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=rocha
# 63 of 500
# 178093 kipini
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=kipini
# 64 of 500
# 3896218 castro
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=castro
# 65 of 500
# 895057 binga
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=binga
# 66 of 500
# 3689147 puerto colombia
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=puerto colombia
# 67 of 500
# 153871 mikumi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=mikumi
# 68 of 500
# 148141 hadrut
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=hadrut
# 69 of 500
# 943937 villiers
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=villiers
# 70 of 500
# 934292 mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=mahebourg
# 71 of 500
# 4372777 vardo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=vardo
# 72 of 500
# 986717 kruisfontein
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=kruisfontein
# 73 of 500
# 210379 lusambo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=lusambo
# 74 of 500
# 2274895 monrovia
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=monrovia
# 75 of 500
# 2264456 lagoa
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=lagoa
# 76 of 500
# 779554 honningsvag
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=honningsvag
# 77 of 500
# 89113 ajdabiya
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=ajdabiya
# 78 of 500
# 5924351 clyde river
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=clyde river
# 79 of 500
# 2374583 bubaque
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=bubaque
# 80 of 500
# 3874787 punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=punta arenas
# 81 of 500
# 1269328 jamkhandi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=jamkhandi
# 82 of 500
# 5915327 cap-aux-meules
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=cap-aux-meules
# 83 of 500
# 118704 ravar
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=ravar
# 84 of 500
# 2249901 gat
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=gat
# 85 of 500
# 3421765 nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=nanortalik
# 86 of 500
# 3453439 ponta do sol
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=ponta do sol
# 87 of 500
# 2737599 saldanha
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=saldanha
# 88 of 500
# 3451138 rio grande
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=rio grande
# 89 of 500
# 3576994 cockburn town
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=cockburn town
# 90 of 500
# 2385535 kouango
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=kouango
# 91 of 500
# 2281120 tabou
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=tabou
# 92 of 500
# 1267635 karwar
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=karwar
# 93 of 500
# 2702261 kalmar
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=kalmar
# 94 of 500
# 1006984 east london
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=east london
# 95 of 500
# 1487332 verkhnyaya inta
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=verkhnyaya inta
# 96 of 500
# 3408221 agua branca
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=agua branca
# 97 of 500
# 3447997 sarandi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=sarandi
# 98 of 500
# 3026644 souillac
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=souillac
# 99 of 500
# 1052944 angoche
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=angoche
# 100 of 500
# 3897347 calama
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=calama
# 101 of 500
# 2399001 mayumba
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=mayumba
# 102 of 500
# 6096551 pangnirtung
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=pangnirtung
# 103 of 500
# 686967 ozerne
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=ozerne
# 104 of 500
# 934292 bambous virieux
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=bambous virieux
# 105 of 500
# 604490 lulea
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=lulea
# 106 of 500
# 3461465 iguape
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=iguape
# 107 of 500
# 1493197 labytnangi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=labytnangi
# 108 of 500
# 962367 richards bay
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=richards bay
# 109 of 500
# 3466165 cidreira
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=cidreira
# 110 of 500
# 1711004 dingle
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=dingle
# 111 of 500
# 2278158 buchanan
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=buchanan
# 112 of 500
# 1974329 parauna
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=parauna
# 113 of 500
# 2160063 codrington
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=codrington
# 114 of 500
# 3415496 grindavik
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=grindavik
# 115 of 500
# 778707 mehamn
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=mehamn
# 116 of 500
# 2314705 kikwit
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=kikwit
# 117 of 500
# 789988 mana
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=mana
# 118 of 500
# 2740313 belmonte
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=belmonte
# 119 of 500
# 216449 gandajika
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=gandajika
# 120 of 500
# 1512101 agirish
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=agirish
# 121 of 500
# 571634 breytovo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=breytovo
# 122 of 500
# 3378644 georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=georgetown
# 123 of 500
# 2455290 kidal
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=kidal
# 124 of 500
# 3347019 namibe
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=namibe
# 125 of 500
# 98182 baghdad
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=baghdad
# 126 of 500
# 2271772 colares
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=colares
# 127 of 500
# 1259385 port blair
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=port blair
# 128 of 500
# 546633 kokorevka
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=kokorevka
# 129 of 500
# 2636814 stonehaven
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=stonehaven
# 130 of 500
# 3397277 cabedelo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=cabedelo
# 131 of 500
# 108410 riyadh
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=riyadh
# 132 of 500
# 3833883 rawson
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=rawson
# 133 of 500
# 3372783 ponta delgada
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=ponta delgada
# 134 of 500
# 2641673 whitley bay
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=whitley bay
# 135 of 500
# 5983720 iqaluit
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=iqaluit
# 136 of 500
# 556268 ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=ostrovnoy
# 137 of 500
# 3448903 sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=sao joao da barra
# 138 of 500
# 3855065 general roca
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=general roca
# 139 of 500
# 3346821 ondjiva
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=ondjiva
# 140 of 500
# 889942 hwange
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=hwange
# 141 of 500
# 6165406 thompson
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=thompson
# 142 of 500
# 6077243 saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=saint-philippe
# 143 of 500
# 4696310 harper
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=harper
# 144 of 500
# 2450173 taoudenni
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=taoudenni
# 145 of 500
# 3456070 novo cruzeiro
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=novo cruzeiro
# 146 of 500
# 3305808 warmbad
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=warmbad
# 147 of 500
# 57000 hobyo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=hobyo
# 148 of 500
# 3622716 nicoya
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=nicoya
# 149 of 500
# 3382160 cayenne
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=cayenne
# 150 of 500
# 4639045 jackson
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=jackson
# 151 of 500
# 2638010 brae
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=brae
# 152 of 500
# 608271 shubarkuduk
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=shubarkuduk
# 153 of 500
# 5961417 husavik
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=husavik
# 154 of 500
# 3091141 namyslow
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=namyslow
# 155 of 500
# 2209055 waddan
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=waddan
# 156 of 500
# 5889745 baie-comeau
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=baie-comeau
# 157 of 500
# 877581 nanyamba
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=nanyamba
# 158 of 500
# 2831482 visselhovede
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=visselhovede
# 159 of 500
# 3465342 puerto quijarro
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=puerto quijarro
# 160 of 500
# 5972360 grenville
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=grenville
# 161 of 500
# 2256895 mossendjo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=mossendjo
# 162 of 500
# 2212775 sabha
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=sabha
# 163 of 500
# 110690 faya
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=faya
# 164 of 500
# 477958 solginskiy
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=solginskiy
# 165 of 500
# 3374210 sao filipe
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=sao filipe
# 166 of 500
# 1529626 baijiantan
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=baijiantan
# 167 of 500
# 2701680 karlstad
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=karlstad
# 168 of 500
# 1516527 zholymbet
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=zholymbet
# 169 of 500
# 3086153 sepolno krajenskie
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=sepolno krajenskie
# 170 of 500
# 3655673 chota
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=chota
# 171 of 500
# 3603330 amapa
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=amapa
# 172 of 500
# 2303287 bawku
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=bawku
# 173 of 500
# 2847614 heidelberg
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=heidelberg
# 174 of 500
# 5924579 port hope
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=port hope
# 175 of 500
# 893485 chiredzi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=chiredzi
# 176 of 500
# 3355672 luderitz
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=luderitz
# 177 of 500
# 60019 eyl
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=eyl
# 178 of 500
# 2446796 bilma
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=bilma
# 179 of 500
# 204405 uvira
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=uvira
# 180 of 500
# 373141 kaduqli
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=kaduqli
# 181 of 500
# 1699791 san joaquin
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=san joaquin
# 182 of 500
# 3037456 saint-joseph
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=saint-joseph
# 183 of 500
# 1817135 bama
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=bama
# 184 of 500
# 2524881 crotone
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=crotone
# 185 of 500
# 2318123 yenagoa
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=yenagoa
# 186 of 500
# 3451650 resplendor
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=resplendor
# 187 of 500
# 4217625 eatonton
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=eatonton
# 188 of 500
# 2294877 tamale
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=tamale
# 189 of 500
# 2630299 hofn
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=hofn
# 190 of 500
# 3372677 vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=vila franca do campo
# 191 of 500
# 3359638 walvis bay
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=walvis bay
# 192 of 500
# 3357804 eenhana
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=eenhana
# 193 of 500
# 828055 sirtich
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=sirtich
# 194 of 500
# 4755280 danville
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=danville
# 195 of 500
# 3458930 lages
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=lages
# 196 of 500
# 475469 verkhnetulomskiy
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=verkhnetulomskiy
# 197 of 500
# 3572189 high rock
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=high rock
# 198 of 500
# 3385022 carutapera
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=carutapera
# 199 of 500
# 5599930 saint anthony
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=saint anthony
# 200 of 500
# 3461370 imbituba
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=imbituba
# 201 of 500
# 1510030 biskamzha
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=biskamzha
# 202 of 500
# 1264976 leh
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=leh
# 203 of 500
# 1493162 salym
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=salym
# 204 of 500
# 2219235 awbari
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=awbari
# 205 of 500
# 2270023 aveiras de cima
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=aveiras de cima
# 206 of 500
# 286245 sur
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=sur
# 207 of 500
# 3577279 oranjestad
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=oranjestad
# 208 of 500
# 1267390 kavaratti
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=kavaratti
# 209 of 500
# 1337619 ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=ugoofaaru
# 210 of 500
# 1014034 carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=carnarvon
# 211 of 500
# 1062663 mahajanga
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=mahajanga
# 212 of 500
# 3557758 guane
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=guane
# 213 of 500
# 1177446 gwadar
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=gwadar
# 214 of 500
# 1273294 dwarka
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=dwarka
# 215 of 500
# 4159657 sebastian
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=sebastian
# 216 of 500
# 1261748 narsipatnam
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=narsipatnam
# 217 of 500
# 343593 areka
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=areka
# 218 of 500
# 2474871 adrar
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=adrar
# 219 of 500
# 3855075 general pico
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=general pico
# 220 of 500
# 3430443 necochea
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=necochea
# 221 of 500
# 564234 dukhovshchina
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=dukhovshchina
# 222 of 500
# 2439376 tahoua
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=tahoua
# 223 of 500
# 1215502 banda aceh
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=banda aceh
# 224 of 500
# 462444 magnitka
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=magnitka
# 225 of 500
# 3695466 sechura
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=sechura
# 226 of 500
# 304183 bayir
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=bayir
# 227 of 500
# 5898612 gander
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=gander
# 228 of 500
# 286621 salalah
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=salalah
# 229 of 500
# 1067565 beloha
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=beloha
# 230 of 500
# 3433658 gualeguaychu
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=gualeguaychu
# 231 of 500
# 934631 quatre cocos
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=quatre cocos
# 232 of 500
# 2457163 gao
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=gao
# 233 of 500
# 5118116 gloversville
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=gloversville
# 234 of 500
# 53654 mogadishu
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=mogadishu
# 235 of 500
# 2270385 camacha
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=camacha
# 236 of 500
# 3874960 puerto montt
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=puerto montt
# 237 of 500
# 204953 tshikapa
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=tshikapa
# 238 of 500
# 780687 berlevag
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=berlevag
# 239 of 500
# 6538810 agropoli
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=agropoli
# 240 of 500
# 1488414 urengoy
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=urengoy
# 241 of 500
# 2597251 dano
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=dano
# 242 of 500
# 305680 kumluca
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=kumluca
# 243 of 500
# 637314 tornio
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=tornio
# 244 of 500
# 259718 platanos
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=platanos
# 245 of 500
# 3146487 raudeberg
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=raudeberg
# 246 of 500
# 3126369 carballo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=carballo
# 247 of 500
# 1269507 jaisalmer
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=jaisalmer
# 248 of 500
# 3544091 pinar del rio
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=pinar del rio
# 249 of 500
# 3868158 villarrica
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=villarrica
# 250 of 500
# 1502750 kommunisticheskiy
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=kommunisticheskiy
# 251 of 500
# 4925020 valparaiso
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=valparaiso
# 252 of 500
# 1495385 pelym
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=pelym
# 253 of 500
# 2272212 alcacer do sal
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=alcacer do sal
# 254 of 500
# 565778 dobryanka
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=dobryanka
# 255 of 500
# 4286717 campbellsville
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=campbellsville
# 256 of 500
# 3936456 lima
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=lima
# 257 of 500
# 6944112 forestville
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=forestville
# 258 of 500
# 3421193 paamiut
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=paamiut
# 259 of 500
# 3698194 chicama
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=chicama
# 260 of 500
# 5973108 hearst
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=hearst
# 261 of 500
# 1689994 san andres
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=san andres
# 262 of 500
# 142255 bafq
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=bafq
# 263 of 500
# 1505260 polunochnoye
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=polunochnoye
# 264 of 500
# 1241622 wattegama
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=wattegama
# 265 of 500
# 6542001 grumo appula
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=grumo appula
# 266 of 500
# 501177 kamenka
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=kamenka
# 267 of 500
# 3420846 qaqortoq
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=qaqortoq
# 268 of 500
# 3652257 rosa zarate
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=rosa zarate
# 269 of 500
# 1140026 herat
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=herat
# 270 of 500
# 1082243 ambilobe
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=ambilobe
# 271 of 500
# 339734 debre birhan
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=debre birhan
# 272 of 500
# 543396 koygorodok
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=koygorodok
# 273 of 500
# 2995603 saint-pierre
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=saint-pierre
# 274 of 500
# 3662342 sao gabriel da cachoeira
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=sao gabriel da cachoeira
# 275 of 500
# 1519422 semey
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=semey
# 276 of 500
# 3388847 sao felix do xingu
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=sao felix do xingu
# 277 of 500
# 3660689 atocha
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=atocha
# 278 of 500
# 3141332 roros
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=roros
# 279 of 500
# 3577430 road town
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=road town
# 280 of 500
# 1527497 kyzyl-suu
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=kyzyl-suu
# 281 of 500
# 6457400 carbonia
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=carbonia
# 282 of 500
# 2347758 bara
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=bara
# 283 of 500
# 4013704 laguna
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=laguna
# 284 of 500
# 3629710 puerto ayacucho
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=puerto ayacucho
# 285 of 500
# 1214488 meulaboh
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=meulaboh
# 286 of 500
# 1337607 kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=kudahuvadhoo
# 287 of 500
# 552256 karpogory
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=karpogory
# 288 of 500
# 3440034 tacuarembo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=tacuarembo
# 289 of 500
# 1487241 yarkovo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=yarkovo
# 290 of 500
# 3460954 praia
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=praia
# 291 of 500
# 3663524 acu
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=acu
# 292 of 500
# 262462 saint george
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=saint george
# 293 of 500
# 3374084 bathsheba
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=bathsheba
# 294 of 500
# 4011743 constitucion
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=constitucion
# 295 of 500
# 3054543 csemo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=csemo
# 296 of 500
# 2223734 nkoteng
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=nkoteng
# 297 of 500
# 470734 vyatskiye polyany
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=vyatskiye polyany
# 298 of 500
# 1498493 molchanovo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=molchanovo
# 299 of 500
# 1486321 yar-sale
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=yar-sale
# 300 of 500
# 3625710 upata
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=upata
# 301 of 500
# 6316343 alta floresta
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=alta floresta
# 302 of 500
# 1711032 luba
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=luba
# 303 of 500
# 236524 rafai
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=rafai
# 304 of 500
# 1244926 hambantota
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=hambantota
# 305 of 500
# 3408424 ipixuna
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=ipixuna
# 306 of 500
# 70979 sayyan
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=sayyan
# 307 of 500
# 3893629 coquimbo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=coquimbo
# 308 of 500
# 2294291 bolgatanga
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=bolgatanga
# 309 of 500
# 3939168 huarmey
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=huarmey
# 310 of 500
# 728193 kochevo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=kochevo
# 311 of 500
# 6360667 santona
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=santona
# 312 of 500
# 1252795 yanam
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=yanam
# 313 of 500
# 359783 asyut
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=asyut
# 314 of 500
# 3056508 rajec
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=rajec
# 315 of 500
# 164947 salamiyah
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=salamiyah
# 316 of 500
# 2413070 nioro
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=nioro
# 317 of 500
# 495062 chebsara
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=chebsara
# 318 of 500
# 5024237 callaway
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=callaway
# 319 of 500
# 2339468 jalingo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=jalingo
# 320 of 500
# 3654410 pacocha
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=pacocha
# 321 of 500
# 3577844 dovers
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=dovers
# 322 of 500
# 3034125 beaune
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=beaune
# 323 of 500
# 145724 lucapa
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=lucapa
# 324 of 500
# 554397 kalach-na-donu
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=kalach-na-donu
# 325 of 500
# 157960 kibondo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=kibondo
# 326 of 500
# 544896 korenovsk
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=korenovsk
# 327 of 500
# 1508879 bogandinskiy
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=bogandinskiy
# 328 of 500
# 3395981 maceio
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=maceio
# 329 of 500
# 1179758 diplo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=diplo
# 330 of 500
# 3894426 coihaique
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=coihaique
# 331 of 500
# 244878 biltine
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=biltine
# 332 of 500
# 6323121 florianopolis
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=florianopolis
# 333 of 500
# 1707667 marawi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=marawi
# 334 of 500
# 4484186 elizabeth city
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=elizabeth city
# 335 of 500
# 1486910 komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=komsomolskiy
# 336 of 500
# 5960603 geraldton
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=geraldton
# 337 of 500
# 87205 darnah
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=darnah
# 338 of 500
# 1071296 antalaha
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=antalaha
# 339 of 500
# 5393068 santa cruz
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=santa cruz
# 340 of 500
# 2460954 araouane
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=araouane
# 341 of 500
# 3386177 trairi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=trairi
# 342 of 500
# 5972291 havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=havre-saint-pierre
# 343 of 500
# 371745 kutum
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=kutum
# 344 of 500
# 2377450 nouakchott
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=nouakchott
# 345 of 500
# 579999 germenchik
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=germenchik
# 346 of 500
# 107304 buraydah
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=buraydah
# 347 of 500
# 2653945 truro
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=truro
# 348 of 500
# ...
# 417 of 500
# 2964820 skibbereen
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=skibbereen
# 418 of 500
# 924732 nkhata bay
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=nkhata bay
# 419 of 500
# 2214827 mizdah
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=mizdah
# 420 of 500
# 3465536 corbelia
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=corbelia
# 421 of 500
# 3471896 aquidauana
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=aquidauana
# 422 of 500
# 6144312 sept-iles
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=sept-iles
# 423 of 500
# 7626370 bud
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=bud
# 424 of 500
# 521773 nikolsk
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=nikolsk
# 425 of 500
# 2618795 klaksvik
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=klaksvik
# 426 of 500
# 527321 mezen
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=mezen
# 427 of 500
# 3398428 humberto de campos
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=humberto de campos
# 428 of 500
# 2997576 hennebont
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=hennebont
# 429 of 500
# 3406160 sao jose da coroa grande
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=sao jose da coroa grande
# 430 of 500
# 2294915 takoradi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=takoradi
# 431 of 500
# 934212 grand gaube
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=grand gaube
# 432 of 500
# 3163392 roald
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=roald
# 433 of 500
# 3020850 draguignan
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=draguignan
# 434 of 500
# 214614 kamina
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=kamina
# 435 of 500
# 2781194 koszeg
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=koszeg
# 436 of 500
# 3899695 ancud
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=ancud
# 437 of 500
# 1039536 inhambane
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=inhambane
# 438 of 500
# 3201047 dubrovnik
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=dubrovnik
# 439 of 500
# 116996 juybar
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=juybar
# 440 of 500
# 1277643 balangir
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=balangir
# 441 of 500
# 701822 sartana
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=sartana
# 442 of 500
# 1506268 gornopravdinsk
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=gornopravdinsk
# 443 of 500
# 3421319 nuuk
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=nuuk
# 444 of 500
# 3451126 bonfim
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=bonfim
# 445 of 500
# 3424901 aasiaat
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=aasiaat
# 446 of 500
# 3899539 antofagasta
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=antofagasta
# 447 of 500
# 2163355 margate
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=margate
# 448 of 500
# 565289 donskoye
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=donskoye
# 449 of 500
# 209610 kindu
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=kindu
# 450 of 500
# 230893 kitgum
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=kitgum
# 451 of 500
# 1277084 baran
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=baran
# 452 of 500
# 1267065 khanapur
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=khanapur
# 453 of 500
# 602912 skelleftea
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=skelleftea
# 454 of 500
# 3137469 sorland
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=sorland
# 455 of 500
# 364933 umm kaddadah
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=umm kaddadah
# 456 of 500
# 6639619 saint-raymond
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=saint-raymond
# 457 of 500
# 6697807 tripoli
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=tripoli
# 458 of 500
# 3620680 bluefields
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=bluefields
# 459 of 500
# 4791259 virginia beach
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=virginia beach
# 460 of 500
# 3843123 neuquen
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=neuquen
# 461 of 500
# 898947 senanga
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=senanga
# 462 of 500
# 6542155 trapani
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=trapani
# 463 of 500
# 1517323 zhanakorgan
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=zhanakorgan
# 464 of 500
# 172515 abu samrah
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=abu samrah
# 465 of 500
# 2447938 agadez
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=agadez
# 466 of 500
# 1056899 sambava
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=sambava
# 467 of 500
# 337010 gelemso
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=gelemso
# 468 of 500
# 523812 pushkino
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=pushkino
# 469 of 500
# 3190586 slavonski brod
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=slavonski brod
# 470 of 500
# 483029 alekseyevskaya
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=alekseyevskaya
# 471 of 500
# 1131462 uruzgan
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=uruzgan
# 472 of 500
# 3489440 morant bay
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=morant bay
# 473 of 500
# 172256 yazman
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=yazman
# 474 of 500
# 218680 boende
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=boende
# 475 of 500
# 3659852 inga
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=inga
# 476 of 500
# 3339575 domazlice
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=domazlice
# 477 of 500
# 609906 fort-shevchenko
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=fort-shevchenko
# 478 of 500
# 3616253 siuna
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=siuna
# 479 of 500
# 210939 luebo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=luebo
# 480 of 500
# 2980080 saint-francois
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=saint-francois
# 481 of 500
# 5947866 elliot lake
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=elliot lake
# 482 of 500
# 3664980 boa vista
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=boa vista
# 483 of 500
# 3653307 pedernales
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=pedernales
# 484 of 500
# 3392095 pimenteiras
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=pimenteiras
# 485 of 500
# 3720824 miragoane
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=miragoane
# 486 of 500
# 50814 wajid
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=wajid
# 487 of 500
# 113659 tabas
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=tabas
# 488 of 500
# 2335713 matagami
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=matagami
# 489 of 500
# 693284 sokyryany
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=sokyryany
# 490 of 500
# 576195 bizhbulyak
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=bizhbulyak
# 491 of 500
# 6094201 shelburne
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=shelburne
# 492 of 500
# 4568138 san juan
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=san juan
# 493 of 500
# 467978 kazaki
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=kazaki
# 494 of 500
# 945945 upington
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=upington
# 495 of 500
# 3354077 opuwo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=opuwo
# 496 of 500
# 2659510 naters
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=naters
# 497 of 500
# 2449067 tombouctou
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=tombouctou
# 498 of 500
# 292968 abu dhabi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=abu dhabi
# 499 of 500
# 3673536 orocue
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=orocue
# 500 of 500
# 3450083 santa maria
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=santa maria
# 501 of 500
# 2647400 parkhill
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=parkhill
# 502 of 500
# 3838874 rio cuarto
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=rio cuarto
# 503 of 500
# 3380290 sinnamary
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=sinnamary
# 504 of 500
# 133595 gerash
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=gerash
# 505 of 500
# 1028918 pemba
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=pemba
# 506 of 500
# 2319078 wawa
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=wawa
# 507 of 500
# 921806 mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=mitsamiouli
# 508 of 500
# 3099759 elblag
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=elblag
# 509 of 500
# 934212 cap malheureux
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=cap malheureux
# 510 of 500
# 2645198 kirkwall
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=kirkwall
# 511 of 500
# 6064704 malartic
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=malartic
# 512 of 500
# 3870243 taltal
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=taltal
# 513 of 500
# 1525988 ayagoz
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=ayagoz
# 514 of 500
# 6453331 kristiansund
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=kristiansund
# 515 of 500
# 743881 kastamonu
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=kastamonu
# 516 of 500
# 3919998 cobija
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=cobija
# 517 of 500
# 933211 nokaneng
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=nokaneng
# 518 of 500
# 3435038 dolores
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=dolores
# 519 of 500
# 2991213 saint-louis
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=saint-louis
# 520 of 500
# 2759406 ermelo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=ermelo
# 521 of 500
# 3393764 oeiras
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=oeiras
# 522 of 500
# 3906466 riberalta
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=riberalta
# 523 of 500
# 1526038 atbasar
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=atbasar
# 524 of 500
# 252664 gomfoi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=gomfoi
# 525 of 500
# 1227603 badulla
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=badulla
# 526 of 500
# 1054329 vangaindrano
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=vangaindrano
# 527 of 500
# 2685750 ostersund
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=ostersund
# 528 of 500
# 1337613 kulhudhuffushi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=kulhudhuffushi
# 529 of 500
# 4810630 charleston
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=charleston
# 530 of 500
# 69559 aras
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=aras
# 531 of 500
# 967106 oudtshoorn
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=metric&q=oudtshoorn

# %%
weather = pd.DataFrame(weather_d)
weather.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat    Lng   Temp  \
# 0   Kralendijk          20      BQ  1514062500        74  12.15 -68.27  28.00
# 1    Morondava           8      MG  1514065499       100 -20.30  44.28  25.44
# 2         Szob          75      HU  1514064600        70  47.82  18.87   9.00
# 3    Hithadhoo          68      MV  1514065500       100  -0.60  73.08  28.07
# 4  Port Alfred          12      ZA  1514065309        96 -33.59  26.89  19.47
#
#    Wind Speed
# 0        8.20
# 1        1.81
# 2       10.30
# 3        2.49
# 4        3.49

# %%
# Temperature (F) vs. Latitude Scatterplot
plt.scatter(weather["Temp"], weather["Lat"], c='blue', alpha=0.9, linewidth=.5)
plt.title("Temperature (F) vs. Latitude (12/23/2017)")
plt.xlabel('Temperature')
plt.ylabel('Lattitude')
plt.savefig('temperature_vs_latitude.png')
plt.show()

# %%
# Humidity (%) vs. Latitude Scatterplot
plt.scatter(weather["Humidity"], weather["Lat"], c='blue', alpha=0.9, linewidth=.5)
plt.title("Humidity (%) vs. Latitude (12/23/2017)")
plt.xlabel('Humidity')
plt.ylabel('Lattitude')
plt.savefig('humidity_vs_latitude.png')
plt.show()

# %%
# Cloudiness (%) vs. Latitude Scatterplot
plt.scatter(weather["Cloudiness"], weather["Lat"], c='blue', alpha=0.9, linewidth=.5)
plt.title("Cloudiness (%) vs. Latitude (12/23/2017)")
plt.xlabel('Cloudiness')
plt.ylabel('Lattitude')
plt.savefig('cloudiness_vs_latitude.png')
plt.show()

# %%
# Wind Speed (mph) vs. Latitude Scatterplot
plt.scatter(weather["Wind Speed"], weather["Lat"], c='blue', alpha=0.9, linewidth=.5)
plt.title("Wind Speed (mph) vs. Latitude (12/23/2017)")
plt.xlabel('Wind Speed')
plt.ylabel('Lattitude')
plt.savefig('windspeed_vs_latitude.png')
plt.show()

# %%
# creating weather data out put file
weather.to_csv("weather.csv")
